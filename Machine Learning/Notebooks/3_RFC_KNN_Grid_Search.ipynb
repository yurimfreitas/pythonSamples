# %% [markdown]
# # Grid-Search

# %% [markdown]
# ---
#
#
# [documentação](https://scikit-learn.org/stable/index.html) <br>
# dataset: [fonte](https://www.kaggle.com/datasets/hellbuoy/car-price-prediction?select=CarPrice_Assignment.csv)
#
# ---

# %% [markdown]
# >[Grid-Search](#scrollTo=QoBv84MIUa-h)
#
# >>[1.  vamos importar o dataset](#scrollTo=_78JL1jFVQST)
#
# >>[2.  vamos fazer o train test split](#scrollTo=bP8vEZsNl-gh)
#
# >>[3.  vamos aplicar o GridSearchCV](#scrollTo=Z_3KDut4mKXy)

# %% [markdown]
# ## 1.&nbsp; classificação

# %% [markdown]
# ### 1.1.&nbsp; vamos importar o dataset

# %%
# vamos importar as bibliotecas
import pandas as pd
import numpy as np
# vamos importar o dataframe do ficheiro .csv
df_contract_renewal = pd.read_csv("C:/Users/yfreitas/Documents/pythonSamples/Machine Learning/Files/South_China.csv")

# veja as 5 primeiras linhas do dataframe
df_contract_renewal.head()
# veja a forma do dataframe: quantas linhas, quantas colunas?
df_contract_renewal.shape
# veja a informação sobre o dataframe
df_contract_renewal.info()
# veja a descrição das variáveis numéricas
df_contract_renewal.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     1500 non-null   int64
#  1   Registration_Duration  1500 non-null   int64
#  2   Revenue                1500 non-null   int64
#  3   Cost                   1500 non-null   float64
#  4   Renewal                1500 non-null   bool
# dtypes: bool(1), float64(1), int64(3)
# memory usage: 48.5 KB
#                  ID  Registration_Duration      Revenue         Cost
# count   1500.000000            1500.000000  1500.000000  1500.000000
# mean   10750.500000              33.756000    58.387333     6.191050
# std      433.157015              10.928133    61.862056     8.206847
# min    10001.000000              19.000000    13.000000     0.513600
# 25%    10375.750000              25.000000    28.000000     1.821140
# 50%    10750.500000              33.000000    40.000000     3.735905
# 75%    11125.250000              40.000000    64.000000     7.245237
# max    11500.000000              72.000000   981.000000    96.471200

# %% [markdown]
# ### 1.2.&nbsp; vamos fazer o train test split

# %%
# defina a variável alvo
target_variable = 'Renewal'

# train_test split usando a função train_test_split
X = df_contract_renewal.drop(["ID", target_variable], axis = 1)
y = df_contract_renewal[target_variable]*1

# importe a função train_test_split e defina X_train, X_test, y_train, y_test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size = 0.2,
                                                    random_state = 12,
                                                    stratify = y)

# %% [markdown]
# ### 1.3.&nbsp; vamos aplicar o GridSearchCV, with stratifiedKfold because it is classification KNN

# %%
# Vamos importar as bibliotecas
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    roc_auc_score,
    make_scorer
)

# Vamos definir o cv
skf = StratifiedKFold(n_splits=5)

# Vamos criar o modelo de KNN
knn = KNeighborsClassifier()

# Vamos definir a grid dos hyperparameter
param_grid_knn = {
    'n_neighbors': [3, 5, 7, 9],
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan']
}

# Vamos definir as métricas de scoring
scoring = {
    'accuracy': 'accuracy',
    'roc_auc': 'roc_auc'
}

# Vamos aplicar a grid search ao modelo de KNN
grid_search_knn = GridSearchCV(estimator=knn, param_grid=param_grid_knn, cv=skf, scoring=scoring, refit='roc_auc')
grid_search_knn.fit(X_train, y_train)

# Vamos ver os melhores hyperparameters
best_params_knn = grid_search_knn.best_params_
best_score_knn = grid_search_knn.best_score_
print("Best Parameters for KNN:", best_params_knn)
print("Best Cross-Validation AUC for KNN:", best_score_knn)

# Vamos ver os resultados para cada combinação
pd.DataFrame(grid_search_knn.cv_results_)
# Out:
# Best Parameters for KNN: {'metric': 'manhattan', 'n_neighbors': 9, 'weights': 'uniform'}
# Best Cross-Validation AUC for KNN: 0.71989169590823
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_metric  \
# 0        0.000800      0.000980         0.014864        0.003247    euclidean
# 1        0.001270      0.000970         0.004879        0.003866    euclidean
# 2        0.000808      0.000761         0.013199        0.006662    euclidean
# 3        0.001062      0.000899         0.005759        0.005557    euclidean
# 4        0.001029      0.000918         0.010895        0.007726    euclidean
# 5        0.001004      0.000634         0.003652        0.001939    euclidean
# 6        0.001220      0.000768         0.016069        0.003645    euclidean
# 7        0.001205      0.000984         0.005761        0.004034    euclidean
# 8        0.003684      0.006400         0.008432        0.007045    manhattan
# 9        0.000393      0.000786         0.006722        0.008112    manhattan
# 10       0.000102      0.000205         0.009611        0.008011    manhattan
# 11       0.003323      0.006647         0.003358        0.006717    manhattan
# 12       0.000830      0.001017         0.016540        0.002109    manhattan
# 13       0.000996      0.000889         0.004632        0.003173    manhattan
# 14       0.001174      0.000720         0.011336        0.005714    manhattan
# 15       0.002730      0.005460         0.003667        0.005687    manhattan
#
#    param_n_neighbors param_weights  \
# 0                  3       uniform
# 1                  3      distance
# 2                  5       uniform
# 3                  5      distance
# 4                  7       uniform
# 5                  7      distance
# 6                  9       uniform
# 7                  9      distance
# 8                  3       uniform
# 9                  3      distance
# 10                 5       uniform
# 11                 5      distance
# 12                 7       uniform
# 13                 7      distance
# 14                 9       uniform
# 15                 9      distance
#
#                                                params  split0_test_accuracy  \
# 0   {'metric': 'euclidean', 'n_neighbors': 3, 'wei...              0.650000
# 1   {'metric': 'euclidean', 'n_neighbors': 3, 'wei...              0.658333
# 2   {'metric': 'euclidean', 'n_neighbors': 5, 'wei...              0.637500
# 3   {'metric': 'euclidean', 'n_neighbors': 5, 'wei...              0.633333
# 4   {'metric': 'euclidean', 'n_neighbors': 7, 'wei...              0.691667
# 5   {'metric': 'euclidean', 'n_neighbors': 7, 'wei...              0.670833
# 6   {'metric': 'euclidean', 'n_neighbors': 9, 'wei...              0.687500
# 7   {'metric': 'euclidean', 'n_neighbors': 9, 'wei...              0.679167
# 8   {'metric': 'manhattan', 'n_neighbors': 3, 'wei...              0.625000
# 9   {'metric': 'manhattan', 'n_neighbors': 3, 'wei...              0.645833
# 10  {'metric': 'manhattan', 'n_neighbors': 5, 'wei...              0.641667
# 11  {'metric': 'manhattan', 'n_neighbors': 5, 'wei...              0.645833
# 12  {'metric': 'manhattan', 'n_neighbors': 7, 'wei...              0.666667
# 13  {'metric': 'manhattan', 'n_neighbors': 7, 'wei...              0.650000
# 14  {'metric': 'manhattan', 'n_neighbors': 9, 'wei...              0.687500
# 15  {'metric': 'manhattan', 'n_neighbors': 9, 'wei...              0.662500
#
#     split1_test_accuracy  ...  std_test_accuracy  rank_test_accuracy  \
# 0               0.700000  ...           0.029977                   7
# 1               0.683333  ...           0.020344                  12
# 2               0.679167  ...           0.022883                  11
# 3               0.666667  ...           0.023422                  14
# 4               0.670833  ...           0.012638                   4
# 5               0.662500  ...           0.014767                   8
# 6               0.716667  ...           0.012191                   1
# 7               0.687500  ...           0.015000                   5
# 8               0.687500  ...           0.028504                  14
# 9               0.679167  ...           0.013591                  16
# 10              0.675000  ...           0.019543                   9
# 11              0.675000  ...           0.017159                  13
# 12              0.704167  ...           0.015501                   3
# 13              0.675000  ...           0.021570                   9
# 14              0.704167  ...           0.006667                   1
# 15              0.683333  ...           0.016956                   5
#
#     split0_test_roc_auc  split1_test_roc_auc  split2_test_roc_auc  \
# 0              0.655615             0.709554             0.698864
# 1              0.655091             0.703873             0.706041
# 2              0.668548             0.704172             0.699462
# 3              0.672772             0.696322             0.704919
# 4              0.700882             0.727123             0.691761
# 5              0.689780             0.709143             0.702714
# 6              0.727534             0.742113             0.691836
# 7              0.710937             0.721516             0.699013
# 8              0.643316             0.703648             0.702714
# 9              0.653110             0.695350             0.704134
# 10             0.674006             0.707162             0.709218
# 11             0.678828             0.697667             0.706302
# 12             0.702190             0.733067             0.719049
# 13             0.691388             0.714152             0.715872
# 14             0.737627             0.731983             0.693593
# 15             0.716283             0.714003             0.703723
#
#     split3_test_roc_auc  split4_test_roc_auc  mean_test_roc_auc  \
# 0              0.685260             0.651303           0.680119
# 1              0.681429             0.651040           0.679495
# 2              0.692848             0.674330           0.687872
# 3              0.684471             0.673954           0.686488
# 4              0.706183             0.701187           0.705427
# 5              0.707047             0.693637           0.700464
# 6              0.726279             0.708700           0.719292
# 7              0.716287             0.697769           0.709105
# 8              0.672564             0.656111           0.675671
# 9              0.665202             0.647998           0.673159
# 10             0.703103             0.684021           0.695502
# 11             0.690557             0.675945           0.689860
# 12             0.705131             0.706483           0.713184
# 13             0.698144             0.692961           0.702503
# 14             0.731200             0.705056           0.719892
# 15             0.714635             0.686500           0.707029
#
#     std_test_roc_auc  rank_test_roc_auc
# 0           0.023130                 13
# 1           0.023272                 14
# 2           0.014011                 11
# 3           0.012536                 12
# 4           0.011804                  6
# 5           0.007543                  8
# 6           0.017341                  2
# 7           0.009374                  4
# 8           0.024303                 15
# 9           0.022584                 16
# 10          0.013970                  9
# 11          0.011377                 10
# 12          0.011492                  3
# 13          0.010469                  7
# 14          0.017322                  1
# 15          0.011176                  5
#
# [16 rows x 24 columns]

# %% [markdown]
# ### 1.4. Predict with the best result from grid search

# %%
# Vamos fazer o fit do melhor modelo de KNN
best_knn = grid_search_knn.best_estimator_
y_pred_knn = best_knn.predict(X_test)
y_pred_knn_proba = best_knn.predict_proba(X_test)[:, 1]

# Vamos avaliar as métricas finais
print("\nKNN Model Evaluation")
print("Accuracy:", accuracy_score(y_test, y_pred_knn))
print("AUC-ROC:", roc_auc_score(y_test, y_pred_knn_proba))
print("Classification Report:\n", classification_report(y_test, y_pred_knn))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_knn))
# Out:
# KNN Model Evaluation
# Accuracy: 0.6733333333333333
# AUC-ROC: 0.7066028708133971
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.57      0.42      0.48       110
#            1       0.71      0.82      0.76       190
#
#     accuracy                           0.67       300
#    macro avg       0.64      0.62      0.62       300
# weighted avg       0.66      0.67      0.66       300
#
# Confusion Matrix:
#  [[ 46  64]
#  [ 34 156]]

# %% [markdown]
# ### 1.5. Random Forest Classification with stratifiedKfold and gridsearch

# %%
# Vamos definir o modelo de Random Forest
rf = RandomForestClassifier(random_state=42)

# Vamos definir a grid para os hyperparameters
param_grid_rf = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10]
}

# Vamos aplicar a grid search ao modelo de Random Forest
grid_search_rf = GridSearchCV(estimator=rf, param_grid=param_grid_rf, cv=skf, scoring=scoring, refit='roc_auc')
grid_search_rf.fit(X_train, y_train)

# Vamos ver os melhores hyperparameters
best_params_rf = grid_search_rf.best_params_
best_score_rf = grid_search_rf.best_score_
print("Best Parameters for Random Forest:", best_params_rf)
print("Best Cross-Validation AUC for Random Forest:", best_score_rf)

# Vamos ver os resultados para cada combinação
pd.DataFrame(grid_search_rf.cv_results_)
# Out:
# Best Parameters for Random Forest: {'max_depth': 20, 'min_samples_split': 10, 'n_estimators': 50}
# Best Cross-Validation AUC for Random Forest: 0.7671537781825226
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.071793      0.006479         0.004565        0.005978
# 1        0.139065      0.007200         0.005235        0.005124
# 2        0.272566      0.007723         0.024715        0.008714
# 3        0.068115      0.007716         0.008481        0.007059
# 4        0.129453      0.007157         0.010506        0.007522
# 5        0.249755      0.007636         0.025995        0.008672
# 6        0.064560      0.006225         0.006251        0.007656
# 7        0.126228      0.007727         0.006752        0.007330
# 8        0.241707      0.007636         0.025122        0.006950
# 9        0.055238      0.007171         0.014943        0.003658
# 10       0.120548      0.005812         0.015338        0.000747
# 11       0.247410      0.008226         0.022597        0.008616
# 12       0.063920      0.004733         0.006507        0.007487
# 13       0.122778      0.007882         0.013810        0.007358
# 14       0.250894      0.019593         0.022760        0.006826
# 15       0.063317      0.004578         0.006288        0.007701
# 16       0.113992      0.003491         0.015608        0.000442
# 17       0.233852      0.002860         0.019700        0.007830
# 18       0.063998      0.006148         0.010150        0.008346
# 19       0.134540      0.004871         0.012434        0.009144
# 20       0.262532      0.006829         0.023089        0.008672
# 21       0.070987      0.003628         0.003126        0.006252
# 22       0.126485      0.006197         0.012756        0.006384
# 23       0.249951      0.004074         0.026653        0.006366
# 24       0.061606      0.006862         0.006257        0.007663
# 25       0.126881      0.006116         0.006314        0.007733
# 26       0.237579      0.005908         0.025043        0.007679
# 27       0.065331      0.005411         0.008987        0.007431
# 28       0.132606      0.000982         0.014242        0.007281
# 29       0.266044      0.002695         0.019804        0.004788
# 30       0.064565      0.005145         0.008603        0.007161
# 31       0.126117      0.006704         0.010582        0.008265
# 32       0.254377      0.007155         0.019170        0.007955
# 33       0.064033      0.007301         0.007565        0.006753
# 34       0.120821      0.008861         0.010955        0.008626
# 35       0.242402      0.009433         0.021852        0.006577
#
#    param_max_depth param_min_samples_split param_n_estimators  \
# 0             None                       2                 50
# 1             None                       2                100
# 2             None                       2                200
# 3             None                       5                 50
# 4             None                       5                100
# 5             None                       5                200
# 6             None                      10                 50
# 7             None                      10                100
# 8             None                      10                200
# 9               10                       2                 50
# 10              10                       2                100
# 11              10                       2                200
# 12              10                       5                 50
# 13              10                       5                100
# 14              10                       5                200
# 15              10                      10                 50
# 16              10                      10                100
# 17              10                      10                200
# 18              20                       2                 50
# 19              20                       2                100
# 20              20                       2                200
# 21              20                       5                 50
# 22              20                       5                100
# 23              20                       5                200
# 24              20                      10                 50
# 25              20                      10                100
# 26              20                      10                200
# 27              30                       2                 50
# 28              30                       2                100
# 29              30                       2                200
# 30              30                       5                 50
# 31              30                       5                100
# 32              30                       5                200
# 33              30                      10                 50
# 34              30                      10                100
# 35              30                      10                200
#
#                                                params  split0_test_accuracy  \
# 0   {'max_depth': None, 'min_samples_split': 2, 'n...              0.670833
# 1   {'max_depth': None, 'min_samples_split': 2, 'n...              0.687500
# 2   {'max_depth': None, 'min_samples_split': 2, 'n...              0.691667
# 3   {'max_depth': None, 'min_samples_split': 5, 'n...              0.695833
# 4   {'max_depth': None, 'min_samples_split': 5, 'n...              0.675000
# 5   {'max_depth': None, 'min_samples_split': 5, 'n...              0.683333
# 6   {'max_depth': None, 'min_samples_split': 10, '...              0.720833
# 7   {'max_depth': None, 'min_samples_split': 10, '...              0.725000
# 8   {'max_depth': None, 'min_samples_split': 10, '...              0.700000
# 9   {'max_depth': 10, 'min_samples_split': 2, 'n_e...              0.708333
# 10  {'max_depth': 10, 'min_samples_split': 2, 'n_e...              0.695833
# 11  {'max_depth': 10, 'min_samples_split': 2, 'n_e...              0.695833
# 12  {'max_depth': 10, 'min_samples_split': 5, 'n_e...              0.712500
# 13  {'max_depth': 10, 'min_samples_split': 5, 'n_e...              0.704167
# 14  {'max_depth': 10, 'min_samples_split': 5, 'n_e...              0.695833
# 15  {'max_depth': 10, 'min_samples_split': 10, 'n_...              0.720833
# 16  {'max_depth': 10, 'min_samples_split': 10, 'n_...              0.720833
# 17  {'max_depth': 10, 'min_samples_split': 10, 'n_...              0.712500
# 18  {'max_depth': 20, 'min_samples_split': 2, 'n_e...              0.679167
# 19  {'max_depth': 20, 'min_samples_split': 2, 'n_e...              0.695833
# 20  {'max_depth': 20, 'min_samples_split': 2, 'n_e...              0.691667
# 21  {'max_depth': 20, 'min_samples_split': 5, 'n_e...              0.695833
# 22  {'max_depth': 20, 'min_samples_split': 5, 'n_e...              0.675000
# 23  {'max_depth': 20, 'min_samples_split': 5, 'n_e...              0.687500
# 24  {'max_depth': 20, 'min_samples_split': 10, 'n_...              0.720833
# 25  {'max_depth': 20, 'min_samples_split': 10, 'n_...              0.725000
# 26  {'max_depth': 20, 'min_samples_split': 10, 'n_...              0.700000
# 27  {'max_depth': 30, 'min_samples_split': 2, 'n_e...              0.670833
# 28  {'max_depth': 30, 'min_samples_split': 2, 'n_e...              0.687500
# 29  {'max_depth': 30, 'min_samples_split': 2, 'n_e...              0.691667
# 30  {'max_depth': 30, 'min_samples_split': 5, 'n_e...              0.695833
# 31  {'max_depth': 30, 'min_samples_split': 5, 'n_e...              0.675000
# 32  {'max_depth': 30, 'min_samples_split': 5, 'n_e...              0.683333
# 33  {'max_depth': 30, 'min_samples_split': 10, 'n_...              0.720833
# 34  {'max_depth': 30, 'min_samples_split': 10, 'n_...              0.725000
# 35  {'max_depth': 30, 'min_samples_split': 10, 'n_...              0.700000
#
#     split1_test_accuracy  ...  std_test_accuracy  rank_test_accuracy  \
# 0               0.704167  ...           0.013591                  32
# 1               0.716667  ...           0.012191                  35
# 2               0.708333  ...           0.006770                  30
# 3               0.725000  ...           0.010069                  22
# 4               0.725000  ...           0.021344                  22
# 5               0.729167  ...           0.018745                  16
# 6               0.733333  ...           0.010069                   4
# 7               0.737500  ...           0.010737                   4
# 8               0.737500  ...           0.015501                  10
# 9               0.725000  ...           0.007638                  13
# 10              0.720833  ...           0.013281                  21
# 11              0.725000  ...           0.009718                  22
# 12              0.708333  ...           0.006972                  18
# 13              0.712500  ...           0.007728                  15
# 14              0.729167  ...           0.014337                  14
# 15              0.733333  ...           0.010737                   1
# 16              0.737500  ...           0.008165                   1
# 17              0.733333  ...           0.012528                   3
# 18              0.700000  ...           0.010341                  28
# 19              0.716667  ...           0.010069                  32
# 20              0.712500  ...           0.009647                  28
# 21              0.725000  ...           0.011180                  19
# 22              0.716667  ...           0.020750                  27
# 23              0.729167  ...           0.017480                  19
# 24              0.733333  ...           0.010069                   4
# 25              0.737500  ...           0.010737                   4
# 26              0.737500  ...           0.015501                  10
# 27              0.704167  ...           0.013591                  32
# 28              0.716667  ...           0.012191                  35
# 29              0.708333  ...           0.006770                  30
# 30              0.725000  ...           0.010069                  22
# 31              0.725000  ...           0.021344                  22
# 32              0.729167  ...           0.018745                  16
# 33              0.733333  ...           0.010069                   4
# 34              0.737500  ...           0.010737                   4
# 35              0.737500  ...           0.015501                  10
#
#     split0_test_roc_auc  split1_test_roc_auc  split2_test_roc_auc  \
# 0              0.743795             0.772316             0.737104
# 1              0.752579             0.772802             0.730226
# 2              0.744655             0.765513             0.737403
# 3              0.756728             0.778297             0.729366
# 4              0.758373             0.770634             0.736693
# 5              0.756878             0.772279             0.748804
# 6              0.773176             0.791717             0.758971
# 7              0.770634             0.790147             0.756429
# 8              0.767120             0.787679             0.760840
# 9              0.762261             0.773475             0.748056
# 10             0.763831             0.777063             0.751121
# 11             0.763233             0.776316             0.756953
# 12             0.766373             0.783119             0.747682
# 13             0.767195             0.781026             0.743870
# 14             0.763681             0.780727             0.751944
# 15             0.768391             0.788801             0.762635
# 16             0.769513             0.786109             0.764130
# 17             0.771755             0.781773             0.766447
# 18             0.745290             0.773587             0.734525
# 19             0.755308             0.771718             0.727833
# 20             0.746000             0.765064             0.735197
# 21             0.756728             0.778970             0.728992
# 22             0.756728             0.770783             0.735945
# 23             0.757252             0.771606             0.747608
# 24             0.773176             0.791492             0.759644
# 25             0.770634             0.790296             0.756504
# 26             0.767120             0.787904             0.761812
# 27             0.743795             0.772316             0.737104
# 28             0.752579             0.772802             0.730226
# 29             0.744655             0.765513             0.737403
# 30             0.756728             0.778297             0.729366
# 31             0.758373             0.770634             0.736693
# 32             0.756878             0.772279             0.748804
# 33             0.773176             0.791717             0.758971
# 34             0.770634             0.790147             0.756429
# 35             0.767120             0.787679             0.760840
#
#     split3_test_roc_auc  split4_test_roc_auc  mean_test_roc_auc  \
# 0              0.751709             0.720419           0.745069
# 1              0.748854             0.725678           0.746028
# 2              0.749831             0.720795           0.743639
# 3              0.755052             0.724363           0.748761
# 4              0.764030             0.719781           0.749902
# 5              0.766960             0.732477           0.755479
# 6              0.762527             0.748929           0.767064
# 7              0.763504             0.748479           0.765838
# 8              0.768462             0.746225           0.766065
# 9              0.746000             0.719480           0.749854
# 10             0.757344             0.726091           0.755090
# 11             0.762302             0.733679           0.758496
# 12             0.760048             0.746300           0.760704
# 13             0.766659             0.742018           0.760153
# 14             0.767110             0.738487           0.760390
# 15             0.766584             0.748178           0.766918
# 16             0.764856             0.746375           0.766197
# 17             0.767636             0.748103           0.767143
# 18             0.752911             0.720645           0.745391
# 19             0.750282             0.724852           0.745999
# 20             0.749493             0.722335           0.743618
# 21             0.755691             0.726767           0.749430
# 22             0.763203             0.722110           0.749754
# 23             0.766359             0.732252           0.755015
# 24             0.762527             0.748929           0.767154
# 25             0.763504             0.748479           0.765883
# 26             0.768462             0.746225           0.766305
# 27             0.751709             0.720419           0.745069
# 28             0.748854             0.725678           0.746028
# 29             0.749831             0.720795           0.743639
# 30             0.755052             0.724363           0.748761
# 31             0.764030             0.719781           0.749902
# 32             0.766960             0.732477           0.755479
# 33             0.762527             0.748929           0.767064
# 34             0.763504             0.748479           0.765838
# 35             0.768462             0.746225           0.766065
#
#     std_test_roc_auc  rank_test_roc_auc
# 0           0.017083                 32
# 1           0.016921                 28
# 2           0.014687                 34
# 3           0.019732                 26
# 4           0.018884                 21
# 5           0.014069                 17
# 6           0.014560                  3
# 7           0.014207                 11
# 8           0.013379                  8
# 9           0.018180                 23
# 10          0.016858                 19
# 11          0.013948                 16
# 12          0.013506                 13
# 13          0.014977                 15
# 14          0.014287                 14
# 15          0.013044                  5
# 16          0.012700                  7
# 17          0.010941                  2
# 18          0.017788                 31
# 19          0.017571                 30
# 20          0.014311                 36
# 21          0.019475                 25
# 22          0.018037                 24
# 23          0.014014                 20
# 24          0.014412                  1
# 25          0.014249                 10
# 26          0.013381                  6
# 27          0.017083                 32
# 28          0.016921                 28
# 29          0.014687                 34
# 30          0.019732                 26
# 31          0.018884                 21
# 32          0.014069                 17
# 33          0.014560                  3
# 34          0.014207                 11
# 35          0.013379                  8
#
# [36 rows x 24 columns]

# %% [markdown]
# ### 1.5. Predict RFC with beat result

# %%
# Vamos fazer o fit do melhor modelo de Random Forest
best_rf = grid_search_rf.best_estimator_
y_pred_rf = best_rf.predict(X_test)
y_pred_rf_proba = best_rf.predict_proba(X_test)[:, 1]

# Vamos avaliar as métricas finais
print("\nRandom Forest Model Evaluation")
print("Accuracy:", accuracy_score(y_test, y_pred_rf))
print("AUC-ROC:", roc_auc_score(y_test, y_pred_rf_proba))
print("Classification Report:\n", classification_report(y_test, y_pred_rf))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_rf))
# Out:
# Random Forest Model Evaluation
# Accuracy: 0.7233333333333334
# AUC-ROC: 0.7449282296650719
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.65      0.53      0.58       110
#            1       0.75      0.84      0.79       190
#
#     accuracy                           0.72       300
#    macro avg       0.70      0.68      0.69       300
# weighted avg       0.72      0.72      0.72       300
#
# Confusion Matrix:
#  [[ 58  52]
#  [ 31 159]]
